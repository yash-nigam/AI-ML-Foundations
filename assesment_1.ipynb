# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/loan-prediction.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.describe(include='all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP002990   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
sns.countplot(x="Loan_Status", data=df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
sns.countplot(x="Gender", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'ApplicantIncome'}>,
#         <Axes: title={'center': 'CoapplicantIncome'}>],
#        [<Axes: title={'center': 'LoanAmount'}>,
#         <Axes: title={'center': 'Loan_Amount_Term'}>],
#        [<Axes: title={'center': 'Credit_History'}>, <Axes: >]],
#       dtype=object)

# %%
sns.countplot(x='Loan_Status',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Married',data=df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
sns.pairplot(data=df,hue='Loan_Status')

# %%
sns.boxplot(x='Loan_Status',y='Gender',data=df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='Gender'>

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df=df.drop("Loan_ID",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
median_loanamount=df["LoanAmount"].median()
median_loanamount
# Out:
# 128.0

# %%
median_loanamount_term=df["Loan_Amount_Term"].median()
median_loanamount_term
# Out:
# 360.0

# %%
median_credit_history=df["Credit_History"].median()
median_credit_history
# Out:
# 1.0

# %%
df["LoanAmount"]=df["LoanAmount"].replace(np.nan,median_loanamount)

# %%
df["Loan_Amount_Term"]=df["Loan_Amount_Term"].replace(np.nan,median_loanamount_term)

# %%
df["Credit_History"]=df["Credit_History"].replace(np.nan,median_credit_history)

# %%
mode_gender=df["Gender"].mode()[0]
mode_gender
# Out:
# 'Male'

# %%
df["Gender"]=df["Gender"].replace(np.nan,mode_gender)

# %%
mode_married=df["Married"].mode()[0]
mode_married
# Out:
# 'Yes'

# %%
df["Married"]=df["Married"].replace(np.nan,mode_married)

# %%
mode_dependents=df["Dependents"].mode()[0]
mode_dependents
# Out:
# '0'

# %%
df["Dependents"]=df["Dependents"].replace(np.nan,mode_dependents)

# %%
mode_self_employed=df["Self_Employed"].mode()[0]
mode_self_employed
# Out:
# 'No'

# %%
df["Self_Employed"]=df["Self_Employed"].replace(np.nan,mode_self_employed)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
df.sample(5)
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 169    Male     Yes          2      Graduate            No             8000
# 421  Female      No          0  Not Graduate            No             2720
# 53     Male     Yes          2      Graduate            No             4616
# 51   Female      No          0      Graduate            No             3086
# 432    Male      No          0      Graduate            No            12876
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 169                0.0       200.0             360.0             1.0
# 421                0.0        80.0             360.0             0.0
# 53                 0.0       134.0             360.0             1.0
# 51                 0.0       120.0             360.0             1.0
# 432                0.0       405.0             360.0             1.0
#
#     Property_Area Loan_Status
# 169     Semiurban           Y
# 421         Urban           N
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat_cols=["Loan_Status","Married","Gender","Dependents","Education","Self_Employed","Property_Area"]
for col in cat_cols:
  df[col]=le.fit_transform(df[col])

# %%
df.sample(5)
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 196       1        0           0          0              0             8333
# 42        1        1           0          0              0             2400
# 18        1        1           0          1              0             4887
# 316       1        1           2          0              0             3717
# 87        1        1           0          0              0             2500
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 196             3750.0       187.0             360.0             1.0
# 42                 0.0        75.0             360.0             1.0
# 18                 0.0       133.0             360.0             1.0
# 316                0.0       120.0             360.0             1.0
# 87              2118.0       104.0             360.0             1.0
#
#      Property_Area  Loan_Status
# 196              0            1
# ...

# %%
from sklearn.model_selection import train_test_split
#df=pd.read_csv("/content/loan_prediction.csv")
df.head()
Y=df["Loan_Status"]
X=df.drop(["Loan_Status"],axis=1)
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model_lr=LogisticRegression()
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))

# 1. Get model predictions
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)

# 2. Get raw counts of correct predictions
correct_train = accuracy_score(Y_train, y_train_pred, normalize=False)
correct_test = accuracy_score(Y_test, y_test_pred, normalize=False)

print(f"Train Correct: {correct_train} out of {len(Y_train)}")
print(f"Test Correct:  {correct_test} out of {len(Y_test)}")

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(Y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_lr.classes_)
disp.plot(cmap="Blues")
plt.title("Logistic Regression - Confusion Matrix (Test)")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8088578088578089
# 0.8162162162162162
# Train Correct: 347.0 out of 429
# Test Correct:  151.0 out of 185

# %%
from sklearn.svm import SVC
model_lr=SVC()
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))
from sklearn.metrics import accuracy_score

# 1. Get model predictions
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)

# 2. Get raw counts of correct predictions
correct_train = accuracy_score(Y_train, y_train_pred, normalize=False)
correct_test = accuracy_score(Y_test, y_test_pred, normalize=False)

print(f"Train Correct: {correct_train} out of {len(Y_train)}")
print(f"Test Correct:  {correct_test} out of {len(Y_test)}")

cm = confusion_matrix(Y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_lr.classes_)
disp.plot(cmap="Blues")
plt.title("Logistic Regression - Confusion Matrix (Test)")
plt.show()
# Out:
# 0.682983682983683
# 0.7081081081081081
# Train Correct: 293.0 out of 429
# Test Correct:  131.0 out of 185

# %%
from sklearn.tree import DecisionTreeClassifier
model_lr=DecisionTreeClassifier()
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))
# Out:
# 1.0
# 0.6972972972972973

# %%
from sklearn.ensemble import BaggingClassifier
model_lr=BaggingClassifier(
    n_estimators=100,
    max_samples=0.5,     # Uses 50% of training rows per tree to force diversity
    max_features=0.5,    # Uses 50% of features per tree to prevent memorization
    oob_score=True,
    random_state=42,
    n_jobs=-1)
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))
# Out:
# 0.916083916083916
# 0.8108108108108109

# %%
from sklearn.ensemble import AdaBoostClassifier
model_lr=AdaBoostClassifier()
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))

# 1. Get model predictions
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)

cm = confusion_matrix(Y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_lr.classes_)
disp.plot(cmap="Blues")
plt.title("Adaboost Classifier - Confusion Matrix (Test)")
plt.show()
# Out:
# 0.8135198135198135
# 0.8108108108108109

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_lr=GradientBoostingClassifier()
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))

# 1. Get model predictions
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)

cm = confusion_matrix(Y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_lr.classes_)
disp.plot(cmap="Blues")
plt.title("Gradient boost- Confusion Matrix (Test)")
plt.show()
# Out:
# 0.8997668997668997
# 0.7891891891891892

# %%
from sklearn.ensemble import RandomForestClassifier
model_lr=RandomForestClassifier()
model_lr.fit(X_train,Y_train)
print(model_lr.score(X_train,Y_train))
print(model_lr.score(X_test,Y_test))
# 1. Get model predictions
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)
cm = confusion_matrix(Y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_lr.classes_)
disp.plot(cmap="Blues")
plt.title("Adaboost Classifier - Confusion Matrix (Test)")
plt.show()
# Out:
# 1.0
# 0.7891891891891892

# %%
df.info()

# %%
import gradio as gr
import pandas as pd

# The 'model_lr' (Logistic Regression model) and 'X_train' (for column order) are already available from previous cells.

def predict_loan_status(Gender, Married, Dependents, Education, Self_Employed,
                        ApplicantIncome, CoapplicantIncome, LoanAmount,
                        Loan_Amount_Term, Credit_History, Property_Area):
    # Map categorical inputs to numerical values based on LabelEncoder logic
    # (assuming alphabetical order for LabelEncoder outputs as seen in previous steps)
    gender_map = {"Female": 0, "Male": 1}
    married_map = {"No": 0, "Yes": 1}
    dependents_map = {"0": 0, "1": 1, "2": 2, "3+": 3}
    education_map = {"Graduate": 0, "Not Graduate": 1}
    self_employed_map = {"No": 0, "Yes": 1}
    property_area_map = {"Rural": 0, "Semiurban": 1, "Urban": 2}

    Gender_encoded = gender_map[Gender]
    Married_encoded = married_map[Married]
    Dependents_encoded = dependents_map[Dependents]
    Education_encoded = education_map[Education]
    Self_Employed_encoded = self_employed_map[Self_Employed]
    Property_Area_encoded = property_area_map[Property_Area]

    # Create a DataFrame for prediction, ensuring column order matches X_train
    input_data = pd.DataFrame([[Gender_encoded, Married_encoded, Dependents_encoded, Education_encoded,
                                Self_Employed_encoded, ApplicantIncome, CoapplicantIncome,
                                LoanAmount, Loan_Amount_Term, Credit_History, Property_Area_encoded]],
                              columns=X_train.columns)

    prediction = model_lr.predict(input_data)[0]

    return "Approved" if prediction == 1 else "Not Approved"

# Define Gradio Interface components
inputs = [
    gr.Dropdown(["Male", "Female"], label="Gender"),
    gr.Dropdown(["Yes", "No"], label="Married"),
    gr.Dropdown(["0", "1", "2", "3+"], label="Dependents"),
    gr.Dropdown(["Graduate", "Not Graduate"], label="Education"),
    gr.Dropdown(["Yes", "No"], label="Self Employed"),
    gr.Number(label="Applicant Income"),
    gr.Number(label="Coapplicant Income"),
    gr.Number(label="Loan Amount"),
    gr.Number(label="Loan Amount Term (in months)"),
    gr.Slider(minimum=0, maximum=1, step=1, label="Credit History (1=Yes, 0=No)"),
    gr.Dropdown(["Rural", "Semiurban", "Urban"], label="Property Area")
]

outputs = gr.Textbox(label="Loan Status Prediction")

# Create and launch the interface
iface = gr.Interface(fn=predict_loan_status, inputs=inputs, outputs=outputs,
                     title="Loan Status Prediction App",
                     description="Predict if a loan will be approved based on applicant details.")
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://13fb2b93761ffdde6f.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://13fb2b93761ffdde6f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# upsampling using resample
from sklearn.utils import resample
import pandas as pd

# Combine X_train and Y_train to resample together
train_data = pd.concat([X_train, Y_train], axis=1)

# Separate majority and minority classes (adjust column name / values to your target)
target_col = Y_train.name
majority = train_data[train_data[target_col] == train_data[target_col].value_counts().idxmax()]
minority = train_data[train_data[target_col] == train_data[target_col].value_counts().idxmin()]

# Counts before upsampling
print(f"Original majority count: {len(majority)}")
print(f"Original minority count: {len(minority)}")
print(f"Original total: {len(train_data)}")

# Upsample minority class to match majority count
minority_upsampled = resample(minority,
                               replace=True,
                               n_samples=len(majority),
                               random_state=42)

train_upsampled = pd.concat([majority, minority_upsampled])

print(f"\nMajority count after upsampling: {len(train_upsampled[train_upsampled[target_col] == train_data[target_col].value_counts().idxmax()])}")
print(f"Minority count after upsampling: {len(minority_upsampled)}")
print(f"Total samples after upsampling: {len(train_upsampled)}")

X_train_up = train_upsampled.drop(target_col, axis=1)
Y_train_up = train_upsampled[target_col]

model_lr_up = LogisticRegression()
model_lr_up.fit(X_train_up, Y_train_up)
print("Upsampled LR")
print(model_lr_up.score(X_train_up, Y_train_up))
print(model_lr_up.score(X_test, Y_test))
# Out:
# Original majority count: 291
# Original minority count: 138
# Original total: 429
#
# Majority count after upsampling: 291
# Minority count after upsampling: 291
# Total samples after upsampling: 582
# Upsampled LR
# 0.7164948453608248
# 0.7243243243243244
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# downsampling
majority_downsampled = resample(majority,
                                 replace=False,
                                 n_samples=len(minority),
                                 random_state=42)

train_downsampled = pd.concat([majority_downsampled, minority])

X_train_down = train_downsampled.drop(target_col, axis=1)
Y_train_down = train_downsampled[target_col]

model_lr_down = LogisticRegression()
model_lr_down.fit(X_train_down, Y_train_down)
print("Downsampled LR")
print(model_lr_down.score(X_train_down, Y_train_down))
print(model_lr_down.score(X_test, Y_test))
# Out:
# Downsampled LR
# 0.7101449275362319
# 0.7405405405405405
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#SMOTE
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_smote, Y_train_smote = smote.fit_resample(X_train, Y_train)

model_lr_smote = LogisticRegression()
model_lr_smote.fit(X_train_smote, Y_train_smote)
print("SMOTE LR")
print(model_lr_smote.score(X_train_smote, Y_train_smote))
print(model_lr_smote.score(X_test, Y_test))
# Out:
# SMOTE LR
# 0.7491408934707904
# 0.7621621621621621
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.ensemble import AdaBoostClassifier

# Without upsampling
model_ada = AdaBoostClassifier(random_state=42)
model_ada.fit(X_train, Y_train)
print("AdaBoost (Original)")
print(model_ada.score(X_train, Y_train))
print(model_ada.score(X_test, Y_test))

# With upsampling
model_ada_up = AdaBoostClassifier(random_state=42)
model_ada_up.fit(X_train_up, Y_train_up)
print("\nAdaBoost (Upsampled)")
print(model_ada_up.score(X_train_up, Y_train_up))
print(model_ada_up.score(X_test, Y_test))
# Out:
# AdaBoost (Original)
# 0.8135198135198135
# 0.8108108108108109
#
# AdaBoost (Upsampled)
# 0.7800687285223368
# 0.7621621621621621
